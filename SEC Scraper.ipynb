# %%
from sec_edgar_downloader import Downloader
import pandas as pd
import os
from bs4 import BeautifulSoup
import re

# %%
def download_10k_filings(ticker):
    if not os.path.isdir(f"./sec-edgar-filings/{ticker}"):
        # dl = Downloader(ticker, "ramorstem2022@gmail.com")
        dl = Downloader(ticker, "ramor12@umd.edu")

        # Download all 10-K filings for the given ticker symbol.
        dl.get("10-K", ticker)
        return True
    return False

# %%
def extract_text(raw_text):
    doc_start_pattern = re.compile(r'<DOCUMENT>')
    doc_end_pattern = re.compile(r'</DOCUMENT>')
    type_pattern = re.compile(r'<TYPE>[^\n]+')
    
    doc_start_is = [x.end() for x in doc_start_pattern.finditer(raw_text)]
    doc_end_is = [x.start() for x in doc_end_pattern.finditer(raw_text)]
    doc_types = [x[len('<TYPE>'):] for x in type_pattern.findall(raw_text)]
    document = {}

    if len(doc_start_is) == 0:
        return None, None

    # Create a loop to go through each section type and save only the 10-K section in the dictionary
    for doc_type, doc_start, doc_end in zip(doc_types, doc_start_is, doc_end_is):
        if doc_type == '10-K':
            document[doc_type] = raw_text[doc_start:doc_end]
    regex = re.compile(r'(>Item(\s|&#160;|&nbsp;)(1A|1B|7A|7|8)\.{0,1})|(ITEM\s(1A|1B|7A|7|8))')

    date_match = re.search(r'FILED AS OF DATE:\s+(\d{8})', raw_text)
    filing_date = "-1"

    # Extract the date string
    if date_match:
        filing_date = date_match.group(1)
        filing_date = pd.to_datetime(filing_date)

    # print(filing_date)

    matches = regex.finditer(document['10-K'])

    # Create the dataframe
    filing_df = pd.DataFrame([(x.group(), x.start(), x.end()) for x in matches])

    filing_df.columns = ['item', 'start', 'end']
    filing_df['item'] = filing_df.item.str.lower()

    # Get rid of unnesesary charcters from the dataframe
    filing_df.replace('&#160;',' ',regex=True,inplace=True)
    filing_df.replace('&nbsp;',' ',regex=True,inplace=True)
    filing_df.replace(' ','',regex=True,inplace=True)
    filing_df.replace('\.','',regex=True,inplace=True)
    filing_df.replace('>','',regex=True,inplace=True)

    pos_dat = filing_df.sort_values('start', ascending=True).drop_duplicates(subset=['item'], keep='last')
    pos_dat.set_index('item', inplace=True)

    item_1a_raw = document['10-K'][pos_dat['start'].loc['item1a']:pos_dat['start'].loc['item1b']]
    # item_7_raw = document['10-K'][pos_dat['start'].loc['item7']:pos_dat['start'].loc['item7a']]
    # item_7a_raw = document['10-K'][pos_dat['start'].loc['item7a']:pos_dat['start'].loc['item8']]

    item_1a_content = BeautifulSoup(item_1a_raw, 'lxml')
    risk_factors_text = item_1a_content.get_text()
    
    risk_factors_text = risk_factors_text.replace("\n", "")
    risk_factors_text = risk_factors_text.replace(">Item 1A", "")
    risk_factors_text = risk_factors_text.replace(">Item 1A.", "")
    risk_factors_text = risk_factors_text.strip(" ")
    risk_factors_text = risk_factors_text.strip(".")
    risk_factors_text = risk_factors_text.strip(" ")
    risk_factors_text = risk_factors_text.replace("Risk Factors", "Risk Factors\n")
    return filing_date, risk_factors_text

def process_10k_filings(ticker, company_name, base_directory):
    filings_df = pd.DataFrame(columns=["Ticker", "Company Name", "Fill Date", "Risk Factors Text"])

    # Walk through the directory structure
    for root, dirs, files in os.walk(base_directory):
        for file in files:
            try:
                if file.endswith('.txt'):
                    file_path = os.path.join(root, file)
                    with open(file_path, 'r', encoding='utf-8') as f:
                        content = f.read()
                        filing_date, risk_section = extract_text(content)
                        if risk_section:                            
                            filings_df = pd.concat([filings_df, pd.DataFrame.from_records([{
                                "Ticker": ticker,
                                "Company Name": company_name,
                                "Fill Date": filing_date,
                                "Risk Factors Text": risk_section
                            }])], ignore_index=True)
            except:
                pass

    return filings_df

# ticker = "AAPL"
# # download_10k_filings("MSFT")
# # Specify the directory where your 10-K filings are stored
# base_directory = f'./sec-edgar-filings/{ticker}/10-K'

# output_directory = f'{ticker}.csv'
# company_name = "Apple Inc."
# output_df = process_10k_filings(ticker, company_name, base_directory)
# output_df = output_df.sort_values(by="Fill Date", ascending=False)
# output_df.to_csv(output_directory)

# output_df

# %%
companies = pd.read_csv("companies.csv")
companies
# Out:
#                       company name   gvkey   NAICS   SIC ticker  \
# 0                         AAR CORP    1004  423860  5080    AIR
# 1      AMERICAN AIRLINES GROUP INC    1045  481111  4512    AAL
# 2          CECO ENVIRONMENTAL CORP    1050  333413  3564   CECE
# 3                         AVX CORP    1072  334416  3670    AVX
# 4       PINNACLE WEST CAPITAL CORP    1075    2211  4911    PNW
# ...                            ...     ...     ...   ...    ...
# 3796  LYONDELLBASELL INDUSTRIES NV  294524  325220  2820    LYB
# 3797   PLATFORM SPECIALTY PRODUCTS  315318  325320  2870    PAH
# 3798                  ALLEGION PLC  316056  332510  3420   ALLE
# 3799                DORIAN LPG LTD  317264  483111  4412    LPG
# 3800            ATHENE HOLDING LTD  318728  524113  6311    ATH
#
#      industry sector                         weburl  ff5 sector
# 0              Whlsl                    aarcorp.com           1
# 1              Trans                         aa.com           5
# 2               Mach                 cecoenviro.com           2
# 3              Chips                        avx.com           3
# 4               Util               pinnaclewest.com           2
# ...              ...                            ...         ...
# 3796           Chems             lyondellbasell.com           2
# 3797           Chems  platformspecialtyproducts.com           2
# 3798           BldMt                   allegion.com           2
# 3799           Trans                  dorianlpg.com           5
# 3800           Insur                  awdoffice.com           5
#
# [3801 rows x 8 columns]

# %%
ff5_dir_map = {
    1: "Consumer",
    2: "Manufacturing",
    3: "HiTec",
    4: "Health and Medical",
    5: "Other including Finance",
}

for index, company_row in companies.iterrows():
    company_name = company_row["company name"]
    ticker = company_row["ticker"]
    sector = company_row["ff5 sector"]

    base_directory = f'./sec-edgar-filings/{ticker}/10-K'
    output_directory = f'{ff5_dir_map[sector]}/{ticker}.csv'
    
    if not os.path.isfile(output_directory) and os.path.isdir(output_directory):
        try:
            check = download_10k_filings(ticker)
            
            if not check:
                output_df = process_10k_filings(ticker, company_name, base_directory)
                output_df = output_df.sort_values(by="Fill Date", ascending=False)
                output_df.to_csv(output_directory)
                display(output_df)
                print(f"Parsed {ticker}")
            else:
                print(index)

        except:
            print(f"Could not fetch { company_name }.")
    else:
        print(f"Skip {index}")
# Out:
# Skip 0
# Skip 1
# Skip 2
# Skip 3
# Skip 4
# Skip 5
# Skip 6
# Skip 7
# Skip 8
# Skip 9
# Skip 10
# Skip 11
# Skip 12
# Skip 13
# Skip 14
# Skip 15
# Skip 16
# Skip 17
# Skip 18
# Skip 19
# Skip 20
# Skip 21
# Skip 22
# Skip 23
# Skip 24
# Skip 25
# Skip 26
# Skip 27
# Skip 28
# Skip 29
# Skip 30
# Skip 31
# Skip 32
# Skip 33
# Skip 34
# Skip 35
# Skip 36
# Skip 37
# Skip 38
# Skip 39
# Skip 40
# Skip 41
# Skip 42
# Skip 43
# Skip 44
# Skip 45
# Skip 46
# Skip 47
# Skip 48
# Skip 49
# Skip 50
# Skip 51
# Skip 52
# Skip 53
# Skip 54
# Skip 55
# Skip 56
# Skip 57
# Skip 58
# Skip 59
# Skip 60
# Skip 61
# Skip 62
# Skip 63
# Skip 64
# Skip 65
# Skip 66
# Skip 67
# Skip 68
# Skip 69
# Skip 70
# Skip 71
# Skip 72
# Skip 73
# Skip 74
# Skip 75
# Skip 76
# Skip 77
# Skip 78
# Skip 79
# Skip 80
# Skip 81
# Skip 82
# Skip 83
# Skip 84
# Skip 85
# Skip 86
# Skip 87
# Skip 88
# Skip 89
# Skip 90
# Skip 91
# Skip 92
# Skip 93
# Skip 94
# Skip 95
# Skip 96
# Skip 97
# Skip 98
# Skip 99
# Skip 100
# Skip 101
# Skip 102
# Skip 103
# Skip 104
# Skip 105
# Skip 106
# Skip 107
# Skip 108
# Skip 109
# Skip 110
# Skip 111
# Skip 112
# Skip 113
# Skip 114
# Skip 115
# Skip 116
# Skip 117
# Skip 118
# Skip 119
# Skip 120
# Skip 121
# Skip 122
# Skip 123
# Skip 124
# Skip 125
# Skip 126
# Skip 127
# Skip 128
# Skip 129
# Skip 130
# Skip 131
# Skip 132
# Skip 133
# Skip 134
# Skip 135
# Skip 136
# Skip 137
# Skip 138
# Skip 139
# Skip 140
# Skip 141
# Skip 142
# Skip 143
# Skip 144
# Skip 145
# Skip 146
# Skip 147
# Skip 148
# Skip 149
# Skip 150
# Skip 151
# Skip 152
# Skip 153
# Skip 154
# Skip 155
# Skip 156
# Skip 157
# Skip 158
# Skip 159
# Skip 160
# Skip 161
# Skip 162
# Skip 163
# Skip 164
# Skip 165
# Skip 166
# Skip 167
# Skip 168
# Skip 169
# Skip 170
# Skip 171
# Skip 172
# Skip 173
# Skip 174
# Skip 175
# Skip 176
# Skip 177
# Skip 178
# Skip 179
# Skip 180
# Skip 181
# Skip 182
# Skip 183
# Skip 184
# Skip 185
# Skip 186
# Skip 187
# Skip 188
# Skip 189
# Skip 190
# Skip 191
# Skip 192
# Skip 193
# Skip 194
# Skip 195
# Skip 196
# Skip 197
# Skip 198
# Skip 199
# Skip 200
# Skip 201
# Skip 202
# Skip 203
# Skip 204
# Skip 205
# Skip 206
# Skip 207
# Skip 208
# Skip 209
# Skip 210
# Skip 211
# Skip 212
# Skip 213
# Skip 214
# Skip 215
# Skip 216
# Skip 217
# Skip 218
# Skip 219
# Skip 220
# Skip 221
# Skip 222
# Skip 223
# Skip 224
# Skip 225
# Skip 226
# Skip 227
# Skip 228
# Skip 229
# Skip 230
# Skip 231
# Skip 232
# Skip 233
# Skip 234
# Skip 235
# Skip 236
# Skip 237
# Skip 238
# Skip 239
# Skip 240
# Skip 241
# Skip 242
# Skip 243
# Skip 244
# Skip 245
# Skip 246
# Skip 247
# Skip 248
# Skip 249
# Skip 250
# Skip 251
# Skip 252
# Skip 253
# Skip 254
# Skip 255
# Skip 256
# Skip 257
# Skip 258
# Skip 259
# Skip 260
# Skip 261
# Skip 262
# Skip 263
# Skip 264
# Skip 265
# Skip 266
# Skip 267
# Skip 268
# Skip 269
# Skip 270
# Skip 271
# Skip 272
# Skip 273
# Skip 274
# Skip 275
# Skip 276
# Skip 277
# Skip 278
# Skip 279
# Skip 280
# Skip 281
# Skip 282
# Skip 283
# Skip 284
# Skip 285
# Skip 286
# Skip 287
# Skip 288
# Skip 289
# Skip 290
# Skip 291
# Skip 292
# Skip 293
# Skip 294
# Skip 295
# Skip 296
# Skip 297
# Skip 298
# Skip 299
# Skip 300
# Skip 301
# Skip 302
# Skip 303
# Skip 304
# Skip 305
# Skip 306
# Skip 307
# Skip 308
# Skip 309
# Skip 310
# Skip 311
# Skip 312
# Skip 313
# Skip 314
# Skip 315
# Skip 316
# Skip 317
# Skip 318
# Skip 319
# Skip 320
# Skip 321
# Skip 322
# Skip 323
# Skip 324
# Skip 325
# Skip 326
# Skip 327
# Skip 328
# Skip 329
# Skip 330
# Skip 331
# Skip 332
# Skip 333
# Skip 334
# Skip 335
# Skip 336
# Skip 337
# Skip 338
# Skip 339
# Skip 340
# Skip 341
# Skip 342
# Skip 343
# Skip 344
# Skip 345
# Skip 346
# Skip 347
# Skip 348
# Skip 349
# Skip 350
# Skip 351
# Skip 352
# Skip 353
# Skip 354
# Skip 355
# Skip 356
# Skip 357
# Skip 358
# Skip 359
# Skip 360
# Skip 361
# Skip 362
# Skip 363
# Skip 364
# Skip 365
# Skip 366
# Skip 367
# Skip 368
# Skip 369
# Skip 370
# Skip 371
# Skip 372
# Skip 373
# Skip 374
# Skip 375
# Skip 376
# Skip 377
# Skip 378
# Skip 379
# Skip 380
# Skip 381
# Skip 382
# Skip 383
# Skip 384
# Skip 385
# Skip 386
# Skip 387
# Skip 388
# Skip 389
# Skip 390
# Skip 391
# Skip 392
# Skip 393
# Skip 394
# Skip 395
# Skip 396
# Skip 397
# Skip 398
# Skip 399
# Skip 400
# Skip 401
# Skip 402
# Skip 403
# Skip 404
# Skip 405
# Skip 406
# Skip 407
# Skip 408
# Skip 409
# Skip 410
# Skip 411
# Skip 412
# Skip 413
# Skip 414
# Skip 415
# Skip 416
# Skip 417
# Skip 418
# Skip 419
# Skip 420
# Skip 421
# Skip 422
# Skip 423
# Skip 424
# Skip 425
# Skip 426
# Skip 427
# Skip 428
# Skip 429
# Skip 430
# Skip 431
# Skip 432
# Skip 433
# Skip 434
# Skip 435
# Skip 436
# Skip 437
# Skip 438
# Skip 439
# Skip 440
# Skip 441
# Skip 442
# Skip 443
# Skip 444
# Skip 445
# Skip 446
# Skip 447
# Skip 448
# Skip 449
# Skip 450
# Skip 451
# Skip 452
# Skip 453
# Skip 454
# Skip 455
# Skip 456
# Skip 457
# Skip 458
# Skip 459
# Skip 460
# Skip 461
# Skip 462
# Skip 463
# Skip 464
# Skip 465
# Skip 466
# Skip 467
# Skip 468
# Skip 469
# Skip 470
# Skip 471
# Skip 472
# Skip 473
# Skip 474
# Skip 475
# Skip 476
# Skip 477
# Skip 478
# Skip 479
# Skip 480
# Skip 481
# Skip 482
# Skip 483
# Skip 484
# Skip 485
# Skip 486
# Skip 487
# Skip 488
# Skip 489
# Skip 490
# Skip 491
# Skip 492
# Skip 493
# Skip 494
# Skip 495
# Skip 496
# Skip 497
# Skip 498
# Skip 499
# Skip 500
# Skip 501
# Skip 502
# Skip 503
# Skip 504
# Skip 505
# Skip 506
# Skip 507
# Skip 508
# Skip 509
# Skip 510
# Skip 511
# Skip 512
# Skip 513
# Skip 514
# Skip 515
# Skip 516
# Skip 517
# Skip 518
# Skip 519
# Skip 520
# Skip 521
# Skip 522
# Skip 523
# Skip 524
# Skip 525
# Skip 526
# Skip 527
# Skip 528
# Skip 529
# Skip 530
# Skip 531
# Skip 532
# Skip 533
# Skip 534
# Skip 535
# Skip 536
# Skip 537
# Skip 538
# Skip 539
# Skip 540
# Skip 541
# Skip 542
# Skip 543
# Skip 544
# Skip 545
# Skip 546
# Skip 547
# Skip 548
# Skip 549
# Skip 550
# Skip 551
# Skip 552
# Skip 553
# Skip 554
# Skip 555
# Skip 556
# Skip 557
# Skip 558
# Skip 559
# Skip 560
# Skip 561
# Skip 562
# Skip 563
# Skip 564
# Skip 565
# Skip 566
# Skip 567
# Skip 568
# Skip 569
# Skip 570
# Skip 571
# Skip 572
# Skip 573
# Skip 574
# Skip 575
# Skip 576
# Skip 577
# Skip 578
# Skip 579
# Skip 580
# Skip 581
# Skip 582
# Skip 583
# Skip 584
# Skip 585
# Skip 586
# Skip 587
# Skip 588
# Skip 589
# Skip 590
# Skip 591
# Skip 592
# Skip 593
# Skip 594
# Skip 595
# Skip 596
# Skip 597
# Skip 598
# Skip 599
# Skip 600
# Skip 601
# Skip 602
# Skip 603
# Skip 604
# Skip 605
# Skip 606
# Skip 607
# Skip 608
# Skip 609
# Skip 610
# Skip 611
# Skip 612
# Skip 613
# Skip 614
# Skip 615
# Skip 616
# Skip 617
# Skip 618
# Skip 619
# Skip 620
# Skip 621
# Skip 622
# Skip 623
# Skip 624
# Skip 625
# Skip 626
# Skip 627
# Skip 628
# Skip 629
# Skip 630
# Skip 631
# Skip 632
# Skip 633
# Skip 634
# Skip 635
# Skip 636
# Skip 637
# Skip 638
# Skip 639
# Skip 640
# Skip 641
# Skip 642
# Skip 643
# Skip 644
# Skip 645
# Skip 646
# Skip 647
# Skip 648
# Skip 649
# Skip 650
# Skip 651
# Skip 652
# Skip 653
# Skip 654
# Skip 655
# Skip 656
# Skip 657
# Skip 658
# Skip 659
# Skip 660
# Skip 661
# Skip 662
# Skip 663
# Skip 664
# Skip 665
# Skip 666
# Skip 667
# Skip 668
# Skip 669
# Skip 670
# Skip 671
# Skip 672
# Skip 673
# Skip 674
# Skip 675
# Skip 676
# Skip 677
# Skip 678
# Skip 679
# Skip 680
# Skip 681
# Skip 682
# Skip 683
# Skip 684
# Skip 685
# Skip 686
# Skip 687
# Skip 688
# Skip 689
# Skip 690
# Skip 691
# Skip 692
# Skip 693
# Skip 694
# Skip 695
# Skip 696
# Skip 697
# Skip 698
# Skip 699
# Skip 700
# Skip 701
# Skip 702
# Skip 703
# Skip 704
# Skip 705
# Skip 706
# Skip 707
# Skip 708
# Skip 709
# Skip 710
# Skip 711
# Skip 712
# Skip 713
# Skip 714
# Skip 715
# Skip 716
# Skip 717
# Skip 718
# Skip 719
# Skip 720
# Skip 721
# Skip 722
# Skip 723
# Skip 724
# Skip 725
# Skip 726
# Skip 727
# Skip 728
# Skip 729
# Skip 730
# Skip 731
# Skip 732
# Skip 733
# Skip 734
# Skip 735
# Skip 736
# Skip 737
# Skip 738
# Skip 739
# Skip 740
# Skip 741
# Skip 742
# Skip 743
# Skip 744
# Skip 745
# Skip 746
# Skip 747
# Skip 748
# Skip 749
# Skip 750
# Skip 751
# Skip 752
# Skip 753
# Skip 754
# Skip 755
# Skip 756
# Skip 757
# Skip 758
# Skip 759
# Skip 760
# Skip 761
# Skip 762
# Skip 763
# Skip 764
# Skip 765
# Skip 766
# Skip 767
# Skip 768
# Skip 769
# Skip 770
# Skip 771
# Skip 772
# Skip 773
# Skip 774
# Skip 775
# Skip 776
# Skip 777
# Skip 778
# Skip 779
# Skip 780
# Skip 781
# Skip 782
# Skip 783
# Skip 784
# Skip 785
# Skip 786
# Skip 787
# Skip 788
# Skip 789
# Skip 790
# Skip 791
# Skip 792
# Skip 793
# Skip 794
# Skip 795
# Skip 796
# Skip 797
# Skip 798
# Skip 799
# Skip 800
# Skip 801
# Skip 802
# Skip 803
# Skip 804
# Skip 805
# Skip 806
# Skip 807
# Skip 808
# Skip 809
# Skip 810
# Skip 811
# Skip 812
# Skip 813
# Skip 814
# Skip 815
# Skip 816
# Skip 817
# Skip 818
# Skip 819
# Skip 820
# Skip 821
# Skip 822
# Skip 823
# Skip 824
# Skip 825
# Skip 826
# Skip 827
# Skip 828
# Skip 829
# Skip 830
# Skip 831
# Skip 832
# Skip 833
# Skip 834
# Skip 835
# Skip 836
# Skip 837
# Skip 838
# Skip 839
# Skip 840
# Skip 841
# Skip 842
# Skip 843
# Skip 844
# Skip 845
# Skip 846
# Skip 847
# Skip 848
# Skip 849
# Skip 850
# Skip 851
# Skip 852
# Skip 853
# Skip 854
# Skip 855
# Skip 856
# Skip 857
# Skip 858
# Skip 859
# Skip 860
# Skip 861
# Skip 862
# Skip 863
# Skip 864
# Skip 865
# Skip 866
# Skip 867
# Skip 868
# Skip 869
# Skip 870
# Skip 871
# Skip 872
# Skip 873
# Skip 874
# Skip 875
# Skip 876
# Skip 877
# Skip 878
# Skip 879
# Skip 880
# Skip 881
# Skip 882
# Skip 883
# Skip 884
# Skip 885
# Skip 886
# Skip 887
# Skip 888
# Skip 889
# Skip 890
# Skip 891
# Skip 892
# Skip 893
# Skip 894
# Skip 895
# Skip 896
# Skip 897
# Skip 898
# Skip 899
# Skip 900
# Skip 901
# Skip 902
# Skip 903
# Skip 904
# Skip 905
# Skip 906
# Skip 907
# Skip 908
# Skip 909
# Skip 910
# Skip 911
# Skip 912
# Skip 913
# Skip 914
# Skip 915
# Skip 916
# Skip 917
# Skip 918
# Skip 919
# Skip 920
# Skip 921
# Skip 922
# Skip 923
# Skip 924
# Skip 925
# Skip 926
# Skip 927
# Skip 928
# Skip 929
# Skip 930
# Skip 931
# Skip 932
# Skip 933
# Skip 934
# Skip 935
# Skip 936
# Skip 937
# Skip 938
# Skip 939
# Skip 940
# Skip 941
# Skip 942
# Skip 943
# Skip 944
# Skip 945
# Skip 946
# Skip 947
# Skip 948
# Skip 949
# Skip 950
# Skip 951
# Skip 952
# Skip 953
# Skip 954
# Skip 955
# Skip 956
# Skip 957
# Skip 958
# Skip 959
# Skip 960
# Skip 961
# Skip 962
# Skip 963
# Skip 964
# Skip 965
# Skip 966
# Skip 967
# Skip 968
# Skip 969
# Skip 970
# Skip 971
# Skip 972
# Skip 973
# Skip 974
# Skip 975
# Skip 976
# Skip 977
# Skip 978
# Skip 979
# Skip 980
# Skip 981
# Skip 982
# Skip 983
# Skip 984
# Skip 985
# Skip 986
# Skip 987
# Skip 988
# Skip 989
# Skip 990
# Skip 991
# Skip 992
# Skip 993
# Skip 994
# Skip 995
# Skip 996
# Skip 997
# Skip 998
# Skip 999
# Skip 1000
# Skip 1001
# Skip 1002
# Skip 1003
# Skip 1004
# Skip 1005
# Skip 1006
# Skip 1007
# Skip 1008
# Skip 1009
# Skip 1010
# Skip 1011
# Skip 1012
# Skip 1013
# Skip 1014
# Skip 1015
# Skip 1016
# Skip 1017
# Skip 1018
# Skip 1019
# Skip 1020
# Skip 1021
# Skip 1022
# Skip 1023
# Skip 1024
# Skip 1025
# Skip 1026
# Skip 1027
# Skip 1028
# Skip 1029
# Skip 1030
# Skip 1031
# Skip 1032
# Skip 1033
# Skip 1034
# Skip 1035
# Skip 1036
# Skip 1037
# Skip 1038
# Skip 1039
# Skip 1040
# Skip 1041
# Skip 1042
# Skip 1043
# Skip 1044
# Skip 1045
# Skip 1046
# Skip 1047
# Skip 1048
# Skip 1049
# Skip 1050
# Skip 1051
# Skip 1052
# Skip 1053
# Skip 1054
# Skip 1055
# Skip 1056
# Skip 1057
# Skip 1058
# Skip 1059
# Skip 1060
# Skip 1061
# Skip 1062
# Skip 1063
# Skip 1064
# Skip 1065
# Skip 1066
# Skip 1067
# Skip 1068
# Skip 1069
# Skip 1070
# Skip 1071
# Skip 1072
# Skip 1073
# Skip 1074
# Skip 1075
# Skip 1076
# Skip 1077
# Skip 1078
# Skip 1079
# Skip 1080
# Skip 1081
# Skip 1082
# Skip 1083
# Skip 1084
# Skip 1085
# Skip 1086
# Skip 1087
# Skip 1088
# Skip 1089
# Skip 1090
# Skip 1091
# Skip 1092
# Skip 1093
# Skip 1094
# Skip 1095
# Skip 1096
# Skip 1097
# Skip 1098
# Skip 1099
# Skip 1100
# Skip 1101
# Skip 1102
# Skip 1103
# Skip 1104
# Skip 1105
# Skip 1106
# Skip 1107
# Skip 1108
# Skip 1109
# Skip 1110
# Skip 1111
# Skip 1112
# Skip 1113
# Skip 1114
# Skip 1115
# Skip 1116
# Skip 1117
# Skip 1118
# Skip 1119
# Skip 1120
# Skip 1121
# Skip 1122
# Skip 1123
# Skip 1124
# Skip 1125
# Skip 1126
# Skip 1127
# Skip 1128
# Skip 1129
# Skip 1130
# Skip 1131
# Skip 1132
# Skip 1133
# Skip 1134
# Skip 1135
# Skip 1136
# Skip 1137
# Skip 1138
# Skip 1139
# Skip 1140
# Skip 1141
# Skip 1142
# Skip 1143
# Skip 1144
# Skip 1145
# Skip 1146
# Skip 1147
# Skip 1148
# Skip 1149
# Skip 1150
# Skip 1151
# Skip 1152
# Skip 1153
# Skip 1154
# Skip 1155
# Skip 1156
# Skip 1157
# Skip 1158
# Skip 1159
# Skip 1160
# Skip 1161
# Skip 1162
# Skip 1163
# Skip 1164
# Skip 1165
# Skip 1166
# Skip 1167
# Skip 1168
# Skip 1169
# Skip 1170
# Skip 1171
# Skip 1172
# Skip 1173
# Skip 1174
# Skip 1175
# Skip 1176
# Skip 1177
# Skip 1178
# Skip 1179
# Skip 1180
# Skip 1181
# Skip 1182
# Skip 1183
# Skip 1184
# Skip 1185
# Skip 1186
# Skip 1187
# Skip 1188
# Skip 1189
# Skip 1190
# Skip 1191
# Skip 1192
# Skip 1193
# Skip 1194
# Skip 1195
# Skip 1196
# Skip 1197
# Skip 1198
# Skip 1199
# Skip 1200
# Skip 1201
# Skip 1202
# Skip 1203
# Skip 1204
# Skip 1205
# Skip 1206
# Skip 1207
# Skip 1208
# Skip 1209
# Skip 1210
# Skip 1211
# Skip 1212
# Skip 1213
# Skip 1214
# Skip 1215
# Skip 1216
# Skip 1217
# Skip 1218
# Skip 1219
# Skip 1220
# Skip 1221
# Skip 1222
# Skip 1223
# Skip 1224
# Skip 1225
# Skip 1226
# Skip 1227
# Skip 1228
# Skip 1229
# Skip 1230
# Skip 1231
# Skip 1232
# Skip 1233
# Skip 1234
# Skip 1235
# Skip 1236
# Skip 1237
# Skip 1238
# Skip 1239
# Skip 1240
# Skip 1241
# Skip 1242
# Skip 1243
# Skip 1244
# Skip 1245
# Skip 1246
# Skip 1247
# Skip 1248
# Skip 1249
# Skip 1250
# Skip 1251
# Skip 1252
# Skip 1253
# Skip 1254
# Skip 1255
# Skip 1256
# Skip 1257
# Skip 1258
# Skip 1259
# Skip 1260
# Skip 1261
# Skip 1262
# Skip 1263
# Skip 1264
# Skip 1265
# Skip 1266
# Skip 1267
# Skip 1268
# Skip 1269
# Skip 1270
# Skip 1271
# Skip 1272
# Skip 1273
# Skip 1274
# Skip 1275
# Skip 1276
# Skip 1277
# Skip 1278
# Skip 1279
# Skip 1280
# Skip 1281
# Skip 1282
# Skip 1283
# Skip 1284
# Skip 1285
# Skip 1286
# Skip 1287
# Skip 1288
# Skip 1289
# Skip 1290
# Skip 1291
# Skip 1292
# Skip 1293
# Skip 1294
# Skip 1295
# Skip 1296
# Skip 1297
# Skip 1298
# Skip 1299
# Skip 1300
# Skip 1301
# Skip 1302
# Skip 1303
# Skip 1304
# Skip 1305
# Skip 1306
# Skip 1307
# Skip 1308
# Skip 1309
# Skip 1310
# Skip 1311
# Skip 1312
# Skip 1313
# Skip 1314
# Skip 1315
# Skip 1316
# Skip 1317
# Skip 1318
# Skip 1319
# Skip 1320
# Skip 1321
# Skip 1322
# Skip 1323
# Skip 1324
# Skip 1325
# Skip 1326
# Skip 1327
# Skip 1328
# Skip 1329
# Skip 1330
# Skip 1331
# Skip 1332
# Skip 1333
# Skip 1334
# Skip 1335
# Skip 1336
# Skip 1337
# Skip 1338
# Skip 1339
# Skip 1340
# Skip 1341
# Skip 1342
# Skip 1343
# Skip 1344
# Skip 1345
# Skip 1346
# Skip 1347
# Skip 1348
# Skip 1349
# Skip 1350
# Skip 1351
# Skip 1352
# Skip 1353
# Skip 1354
# Skip 1355
# Skip 1356
# Skip 1357
# Skip 1358
# Skip 1359
# Skip 1360
# Skip 1361
# Skip 1362
# Skip 1363
# Skip 1364
# Skip 1365
# Skip 1366
# Skip 1367
# Skip 1368
# Skip 1369
# Skip 1370
# Skip 1371
# Skip 1372
# Skip 1373
# Skip 1374
# Skip 1375
# Skip 1376
# Skip 1377
# Skip 1378
# Skip 1379
# Skip 1380
# Skip 1381
# Skip 1382
# Skip 1383
# Skip 1384
# Skip 1385
# Skip 1386
# Skip 1387
# Skip 1388
# Skip 1389
# Skip 1390
# Skip 1391
# Skip 1392
# Skip 1393
# Skip 1394
# Skip 1395
# Skip 1396
# Skip 1397
# Skip 1398
# Skip 1399
# Skip 1400
# Skip 1401
# Skip 1402
# Skip 1403
# Skip 1404
# Skip 1405
# Skip 1406
# Skip 1407
# Skip 1408
# Skip 1409
# Skip 1410
# Skip 1411
# Skip 1412
# Skip 1413
# Skip 1414
# Skip 1415
# Skip 1416
# Skip 1417
# Skip 1418
# Skip 1419
# Skip 1420
# Skip 1421
# Skip 1422
# Skip 1423
# Skip 1424
# Skip 1425
# Skip 1426
# Skip 1427
# Skip 1428
# Skip 1429
# Skip 1430
# Skip 1431
# Skip 1432
# Skip 1433
# Skip 1434
# Skip 1435
# Skip 1436
# Skip 1437
# Skip 1438
# Skip 1439
# Skip 1440
# Skip 1441
# Skip 1442
# Skip 1443
# Skip 1444
# Skip 1445
# Skip 1446
# Skip 1447
# Skip 1448
# Skip 1449
# Skip 1450
# Skip 1451
# Skip 1452
# Skip 1453
# Skip 1454
# Skip 1455
# Skip 1456
# Skip 1457
# Skip 1458
# Skip 1459
# Skip 1460
# Skip 1461
# Skip 1462
# Skip 1463
# Skip 1464
# Skip 1465
# Skip 1466
# Skip 1467
# Skip 1468
# Skip 1469
# Skip 1470
# Skip 1471
# Skip 1472
# Skip 1473
# Skip 1474
# Skip 1475
# Skip 1476
# Skip 1477
# Skip 1478
# Skip 1479
# Skip 1480
# Skip 1481
# Skip 1482
# Skip 1483
# Skip 1484
# Skip 1485
# Skip 1486
# Skip 1487
# Skip 1488
# Skip 1489
# Skip 1490
# Skip 1491
# Skip 1492
# Skip 1493
# Skip 1494
# Skip 1495
# Skip 1496
# Skip 1497
# Skip 1498
# Skip 1499
# Skip 1500
# Skip 1501
# Skip 1502
# Skip 1503
# Skip 1504
# Skip 1505
# Skip 1506
# Skip 1507
# Skip 1508
# Skip 1509
# Skip 1510
# Skip 1511
# Skip 1512
# Skip 1513
# Skip 1514
# Skip 1515
# Skip 1516
# Skip 1517
# Skip 1518
# Skip 1519
# Skip 1520
# Skip 1521
# Skip 1522
# Skip 1523
# Skip 1524
# Skip 1525
# Skip 1526
# Skip 1527
# Skip 1528
# Skip 1529
# Skip 1530
# Skip 1531
# Skip 1532
# Skip 1533
# Skip 1534
# Skip 1535
# Skip 1536
# Skip 1537
# Skip 1538
# Skip 1539
# Skip 1540
# Skip 1541
# Skip 1542
# Skip 1543
# Skip 1544
# Skip 1545
# Skip 1546
# Skip 1547
# Skip 1548
# Skip 1549
# Skip 1550
# Skip 1551
# Skip 1552
# Skip 1553
# Skip 1554
# Skip 1555
# Skip 1556
# Skip 1557
# Skip 1558
# Skip 1559
# Skip 1560
# Skip 1561
# Skip 1562
# Skip 1563
# Skip 1564
# Skip 1565
# Skip 1566
# Skip 1567
# Skip 1568
# Skip 1569
# Skip 1570
# Skip 1571
# Skip 1572
# Skip 1573
# Skip 1574
# Skip 1575
# Skip 1576
# Skip 1577
# Skip 1578
# Skip 1579
# Skip 1580
# Skip 1581
# Skip 1582
# Skip 1583
# Skip 1584
# Skip 1585
# Skip 1586
# Skip 1587
# Skip 1588
# Skip 1589
# Skip 1590
# Skip 1591
# Skip 1592
# Skip 1593
# Skip 1594
# Skip 1595
# Skip 1596
# Skip 1597
# Skip 1598
# Skip 1599
# Skip 1600
# Skip 1601
# Skip 1602
# Skip 1603
# Skip 1604
# Skip 1605
# Skip 1606
# Skip 1607
# Skip 1608
# Skip 1609
# Skip 1610
# Skip 1611
# Skip 1612
# Skip 1613
# Skip 1614
# Skip 1615
# Skip 1616
# Skip 1617
# Skip 1618
# Skip 1619
# Skip 1620
# Skip 1621
# Skip 1622
# Skip 1623
# Skip 1624
# Skip 1625
# Skip 1626
# Skip 1627
# Skip 1628
# Skip 1629
# Skip 1630
# Skip 1631
# Skip 1632
# Skip 1633
# Skip 1634
# Skip 1635
# Skip 1636
# Skip 1637
# Skip 1638
# Skip 1639
# Skip 1640
# Skip 1641
# Skip 1642
# Skip 1643
# Skip 1644
# Skip 1645
# Skip 1646
# Skip 1647
# Skip 1648
# Skip 1649
# Skip 1650
# Skip 1651
# Skip 1652
# Skip 1653
# Skip 1654
# Skip 1655
# Skip 1656
# Skip 1657
# Skip 1658
# Skip 1659
# Skip 1660
# Skip 1661
# Skip 1662
# Skip 1663
# Skip 1664
# Skip 1665
# Skip 1666
# Skip 1667
# Skip 1668
# Skip 1669
# Skip 1670
# Skip 1671
# Skip 1672
# Skip 1673
# Skip 1674
# Skip 1675
# Skip 1676
# Skip 1677
# Skip 1678
# Skip 1679
# Skip 1680
# Skip 1681
# Skip 1682
# Skip 1683
# Skip 1684
# Skip 1685
# Skip 1686
# Skip 1687
# Skip 1688
# Skip 1689
# Skip 1690
# Skip 1691
# Skip 1692
# Skip 1693
# Skip 1694
# Skip 1695
# Skip 1696
# Skip 1697
# Skip 1698
# Skip 1699
# Skip 1700
# Skip 1701
# Skip 1702
# Skip 1703
# Skip 1704
# Skip 1705
# Skip 1706
# Skip 1707
# Skip 1708
# Skip 1709
# Skip 1710
# Skip 1711
# Skip 1712
# Skip 1713
# Skip 1714
# Skip 1715
# Skip 1716
# Skip 1717
# Skip 1718
# Skip 1719
# Skip 1720
# Skip 1721
# Skip 1722
# Skip 1723
# Skip 1724
# Skip 1725
# Skip 1726
# Skip 1727
# Skip 1728
# Skip 1729
# Skip 1730
# Skip 1731
# Skip 1732
# Skip 1733
# Skip 1734
# Skip 1735
# Skip 1736
# Skip 1737
# Skip 1738
# Skip 1739
# Skip 1740
# Skip 1741
# Skip 1742
# Skip 1743
# Skip 1744
# Skip 1745
# Skip 1746
# Skip 1747
# Skip 1748
# Skip 1749
# Skip 1750
# Skip 1751
# Skip 1752
# Skip 1753
# Skip 1754
# Skip 1755
# Skip 1756
# Skip 1757
# Skip 1758
# Skip 1759
# Skip 1760
# Skip 1761
# Skip 1762
# Skip 1763
# Skip 1764
# Skip 1765
# Skip 1766
# Skip 1767
# Skip 1768
# Skip 1769
# Skip 1770
# Skip 1771
# Skip 1772
# Skip 1773
# Skip 1774
# Skip 1775
# Skip 1776
# Skip 1777
# Skip 1778
# Skip 1779
# Skip 1780
# Skip 1781
# Skip 1782
# Skip 1783
# Skip 1784
# Skip 1785
# Skip 1786
# Skip 1787
# Skip 1788
# Skip 1789
# Skip 1790
# Skip 1791
# Skip 1792
# Skip 1793
# Skip 1794
# Skip 1795
# Skip 1796
# Skip 1797
# Skip 1798
# Skip 1799
# Skip 1800
# Skip 1801
# Skip 1802
# Skip 1803
# Skip 1804
# Skip 1805
# Skip 1806
# Skip 1807
# Skip 1808
# Skip 1809
# Skip 1810
# Skip 1811
# Skip 1812
# Skip 1813
# Skip 1814
# Skip 1815
# Skip 1816
# Skip 1817
# Skip 1818
# Skip 1819
# Skip 1820
# Skip 1821
# Skip 1822
# Skip 1823
# Skip 1824
# Skip 1825
# Skip 1826
# Skip 1827
# Skip 1828
# Skip 1829
# Skip 1830
# Skip 1831
# Skip 1832
# Skip 1833
# Skip 1834
# Skip 1835
# Skip 1836
# Skip 1837
# Skip 1838
# Skip 1839
# Skip 1840
# Skip 1841
# Skip 1842
# Skip 1843
# Skip 1844
# Skip 1845
# Skip 1846
# Skip 1847
# Skip 1848
# Skip 1849
# Skip 1850
# Skip 1851
# Skip 1852
# Skip 1853
# Skip 1854
# Skip 1855
# Skip 1856
# Skip 1857
# Skip 1858
# Skip 1859
# Skip 1860
# Skip 1861
# Skip 1862
# Skip 1863
# Skip 1864
# Skip 1865
# Skip 1866
# Skip 1867
# Skip 1868
# Skip 1869
# Skip 1870
# Skip 1871
# Skip 1872
# Skip 1873
# Skip 1874
# Skip 1875
# Skip 1876
# Skip 1877
# Skip 1878
# Skip 1879
# Skip 1880
# Skip 1881
# Skip 1882
# Skip 1883
# Skip 1884
# Skip 1885
# Skip 1886
# Skip 1887
# Skip 1888
# Skip 1889
# Skip 1890
# Skip 1891
# Skip 1892
# Skip 1893
# Skip 1894
# Skip 1895
# Skip 1896
# Skip 1897
# Skip 1898
# Skip 1899
# Skip 1900
# Skip 1901
# Skip 1902
# Skip 1903
# Skip 1904
# Skip 1905
# Skip 1906
# Skip 1907
# Skip 1908
# Skip 1909
# Skip 1910
# Skip 1911
# Skip 1912
# Skip 1913
# Skip 1914
# Skip 1915
# Skip 1916
# Skip 1917
# Skip 1918
# Skip 1919
# Skip 1920
# Skip 1921
# Skip 1922
# Skip 1923
# Skip 1924
# Skip 1925
# Skip 1926
# Skip 1927
# Skip 1928
# Skip 1929
# Skip 1930
# Skip 1931
# Skip 1932
# Skip 1933
# Skip 1934
# Skip 1935
# Skip 1936
# Skip 1937
# Skip 1938
# Skip 1939
# Skip 1940
# Skip 1941
# Skip 1942
# Skip 1943
# Skip 1944
# Skip 1945
# Skip 1946
# Skip 1947
# Skip 1948
# Skip 1949
# Skip 1950
# Skip 1951
# Skip 1952
# Skip 1953
# Skip 1954
# Skip 1955
# Skip 1956
# Skip 1957
# Skip 1958
# Skip 1959
# Skip 1960
# Skip 1961
# Skip 1962
# Skip 1963
# Skip 1964
# Skip 1965
# Skip 1966
# Skip 1967
# Skip 1968
# Skip 1969
# Skip 1970
# Skip 1971
# Skip 1972
# Skip 1973
# Skip 1974
# Skip 1975
# Skip 1976
# Skip 1977
# Skip 1978
# Skip 1979
# Skip 1980
# Skip 1981
# Skip 1982
# Skip 1983
# Skip 1984
# Skip 1985
# Skip 1986
# Skip 1987
# Skip 1988
# Skip 1989
# Skip 1990
# Skip 1991
# Skip 1992
# Skip 1993
# Skip 1994
# Skip 1995
# Skip 1996
# Skip 1997
# Skip 1998
# Skip 1999
# Skip 2000
# Skip 2001
# Skip 2002
# Skip 2003
# Skip 2004
# Skip 2005
# Skip 2006
# Skip 2007
# Skip 2008
# Skip 2009
# Skip 2010
# Skip 2011
# Skip 2012
# Skip 2013
# Skip 2014
# Skip 2015
# Skip 2016
# Skip 2017
# Skip 2018
# Skip 2019
# Skip 2020
# Skip 2021
# Skip 2022
# Skip 2023
# Skip 2024
# Skip 2025
# Skip 2026
# Skip 2027
# Skip 2028
# Skip 2029
# Skip 2030
# Skip 2031
# Skip 2032
# Skip 2033
# Skip 2034
# Skip 2035
# Skip 2036
# Skip 2037
# Skip 2038
# Skip 2039
# Skip 2040
# Skip 2041
# Skip 2042
# Skip 2043
# Skip 2044
# Skip 2045
# Skip 2046
# Skip 2047
# Skip 2048
# Skip 2049
# Skip 2050
# Skip 2051
# Skip 2052
# Skip 2053
# Skip 2054
# Skip 2055
# Skip 2056
# Skip 2057
# Skip 2058
# Skip 2059
# Skip 2060
# Skip 2061
# Skip 2062
# Skip 2063
# Skip 2064
# Skip 2065
# Skip 2066
# Skip 2067
# Skip 2068
# Skip 2069
# Skip 2070
# Skip 2071
# Skip 2072
# Skip 2073
# Skip 2074
# Skip 2075
# Skip 2076
# Skip 2077
# Skip 2078
# Skip 2079
# Skip 2080
# Skip 2081
# Skip 2082
# Skip 2083
# Skip 2084
# Skip 2085
# Skip 2086
# Skip 2087
# Skip 2088
# Skip 2089
# Skip 2090
# Skip 2091
# Skip 2092
# Skip 2093
# Skip 2094
# Skip 2095
# Skip 2096
# Skip 2097
# Skip 2098
# Skip 2099
# Skip 2100
# Skip 2101
# Skip 2102
# Skip 2103
# Skip 2104
# Skip 2105
# Skip 2106
# Skip 2107
# Skip 2108
# Skip 2109
# Skip 2110
# Skip 2111
# Skip 2112
# Skip 2113
# Skip 2114
# Skip 2115
# Skip 2116
# Skip 2117
# Skip 2118
# Skip 2119
# Skip 2120
# Skip 2121
# Skip 2122
# Skip 2123
# Skip 2124
# Skip 2125
# Skip 2126
# Skip 2127
# Skip 2128
# Skip 2129
# Skip 2130
# Skip 2131
# Skip 2132
# Skip 2133
# Skip 2134
# Skip 2135
# Skip 2136
# Skip 2137
# Skip 2138
# Skip 2139
# Skip 2140
# Skip 2141
# Skip 2142
# Skip 2143
# Skip 2144
# Skip 2145
# Skip 2146
# Skip 2147
# Skip 2148
# Skip 2149
# Skip 2150
# Skip 2151
# Skip 2152
# Skip 2153
# Skip 2154
# Skip 2155
# Skip 2156
# Skip 2157
# Skip 2158
# Skip 2159
# Skip 2160
# Skip 2161
# Skip 2162
# Skip 2163
# Skip 2164
# Skip 2165
# Skip 2166
# Skip 2167
# Skip 2168
# Skip 2169
# Skip 2170
# Skip 2171
# Skip 2172
# Skip 2173
# Skip 2174
# Skip 2175
# Skip 2176
# Skip 2177
# Skip 2178
# Skip 2179
# Skip 2180
# Skip 2181
# Skip 2182
# Skip 2183
# Skip 2184
# Skip 2185
# Skip 2186
# Skip 2187
# Skip 2188
# Skip 2189
# Skip 2190
# Skip 2191
# Skip 2192
# Skip 2193
# Skip 2194
# Skip 2195
# Skip 2196
# Skip 2197
# Skip 2198
# Skip 2199
# Skip 2200
# Skip 2201
# Skip 2202
# Skip 2203
# Skip 2204
# Skip 2205
# Skip 2206
# Skip 2207
# Skip 2208
# Skip 2209
# Skip 2210
# Skip 2211
# Skip 2212
# Skip 2213
# Skip 2214
# Skip 2215
# Skip 2216
# Skip 2217
# Skip 2218
# Skip 2219
# Skip 2220
# Skip 2221
# Skip 2222
# Skip 2223
# Skip 2224
# Skip 2225
# Skip 2226
# Skip 2227
# Skip 2228
# Skip 2229
# Skip 2230
# Skip 2231
# Skip 2232
# Skip 2233
# Skip 2234
# Skip 2235
# Skip 2236
# Skip 2237
# Skip 2238
# Skip 2239
# Skip 2240
# Skip 2241
# Skip 2242
# Skip 2243
# Skip 2244
# Skip 2245
# Skip 2246
# Skip 2247
# Skip 2248
# Skip 2249
# Skip 2250
# Skip 2251
# Skip 2252
# Skip 2253
# Skip 2254
# Skip 2255
# Skip 2256
# Skip 2257
# Skip 2258
# Skip 2259
# Skip 2260
# Skip 2261
# Skip 2262
# Skip 2263
# Skip 2264
# Skip 2265
# Skip 2266
# Skip 2267
# Skip 2268
# Skip 2269
# Skip 2270
# Skip 2271
# Skip 2272
# Skip 2273
# Skip 2274
# Skip 2275
# Skip 2276
# Skip 2277
# Skip 2278
# Skip 2279
# Skip 2280
# Skip 2281
# Skip 2282
# Skip 2283
# Skip 2284
# Skip 2285
# Skip 2286
# Skip 2287
# Skip 2288
# Skip 2289
# Skip 2290
# Skip 2291
# Skip 2292
# Skip 2293
# Skip 2294
# Skip 2295
# Skip 2296
# Skip 2297
# Skip 2298
# Skip 2299
# Skip 2300
# Skip 2301
# Skip 2302
# Skip 2303
# Skip 2304
# Skip 2305
# Skip 2306
# Skip 2307
# Skip 2308
# Skip 2309
# Skip 2310
# Skip 2311
# Skip 2312
# Skip 2313
# Skip 2314
# Skip 2315
# Skip 2316
# Skip 2317
# Skip 2318
# Skip 2319
# Skip 2320
# Skip 2321
# Skip 2322
# Skip 2323
# Skip 2324
# Skip 2325
# Skip 2326
# Skip 2327
# Skip 2328
# Skip 2329
# Skip 2330
# Skip 2331
# Skip 2332
# Skip 2333
# Skip 2334
# Skip 2335
# Skip 2336
# Skip 2337
# Skip 2338
# Skip 2339
# Skip 2340
# Skip 2341
# Skip 2342
# Skip 2343
# Skip 2344
# Skip 2345
# Skip 2346
# Skip 2347
# Skip 2348
# Skip 2349
# Skip 2350
# Skip 2351
# Skip 2352
# Skip 2353
# Skip 2354
# Skip 2355
# Skip 2356
# Skip 2357
# Skip 2358
# Skip 2359
# Skip 2360
# Skip 2361
# Skip 2362
# Skip 2363
# Skip 2364
# Skip 2365
# Skip 2366
# Skip 2367
# Skip 2368
# Skip 2369
# Skip 2370
# Skip 2371
# Skip 2372
# Skip 2373
# Skip 2374
# Skip 2375
# Skip 2376
# Skip 2377
# Skip 2378
# Skip 2379
# Skip 2380
# Skip 2381
# Skip 2382
# Skip 2383
# Skip 2384
# Skip 2385
# Skip 2386
# Skip 2387
# Skip 2388
# Skip 2389
# Skip 2390
# Skip 2391
# Skip 2392
# Skip 2393
# Skip 2394
# Skip 2395
# Skip 2396
# Skip 2397
# Skip 2398
# Skip 2399
# Skip 2400
# Skip 2401
# Skip 2402
# Skip 2403
# Skip 2404
# Skip 2405
# Skip 2406
# Skip 2407
# Skip 2408
# Skip 2409
# Skip 2410
# Skip 2411
# Skip 2412
# Skip 2413
# Skip 2414
# Skip 2415
# Skip 2416
# Skip 2417
# Skip 2418
# Skip 2419
# Skip 2420
# Skip 2421
# Skip 2422
# Skip 2423
# Skip 2424
# Skip 2425
# Skip 2426
# Skip 2427
# Skip 2428
# Skip 2429
# Skip 2430
# Skip 2431
# Skip 2432
# Skip 2433
# Skip 2434
# Skip 2435
# Skip 2436
# Skip 2437
# Skip 2438
# Skip 2439
# Skip 2440
# Skip 2441
# Skip 2442
# Skip 2443
# Skip 2444
# Skip 2445
# Skip 2446
# Skip 2447
# Skip 2448
# Skip 2449
# Skip 2450
# Skip 2451
# Skip 2452
# Skip 2453
# Skip 2454
# Skip 2455
# Skip 2456
# Skip 2457
# Skip 2458
# Skip 2459
# Skip 2460
# Skip 2461
# Skip 2462
# Skip 2463
# Skip 2464
# Skip 2465
# Skip 2466
# Skip 2467
# Skip 2468
# Skip 2469
# Skip 2470
# Skip 2471
# Skip 2472
# Skip 2473
# Skip 2474
# Skip 2475
# Skip 2476
# Skip 2477
# Skip 2478
# Skip 2479
# Skip 2480
# Skip 2481
# Skip 2482
# Skip 2483
# Skip 2484
# Skip 2485
# Skip 2486
# Skip 2487
# Skip 2488
# Skip 2489
# Skip 2490
# Skip 2491
# Skip 2492
# Skip 2493
# Skip 2494
# Skip 2495
# Skip 2496
# Skip 2497
# Skip 2498
# Skip 2499
# Skip 2500
# Skip 2501
# Skip 2502
# Skip 2503
# Skip 2504
# Skip 2505
# Skip 2506
# Skip 2507
# Skip 2508
# Skip 2509
# Skip 2510
# Skip 2511
# Skip 2512
# Skip 2513
# Skip 2514
# Skip 2515
# Skip 2516
# Skip 2517
# Skip 2518
# Skip 2519
# Skip 2520
# Skip 2521
# Skip 2522
# Skip 2523
# Skip 2524
# Skip 2525
# Skip 2526
# Skip 2527
# Skip 2528
# Skip 2529
# Skip 2530
# Skip 2531
# Skip 2532
# Skip 2533
# Skip 2534
# Skip 2535
# Skip 2536
# Skip 2537
# Skip 2538
# Skip 2539
# Skip 2540
# Skip 2541
# Skip 2542
# Skip 2543
# Skip 2544
# Skip 2545
# Skip 2546
# Skip 2547
# Skip 2548
# Skip 2549
# Skip 2550
# Skip 2551
# Skip 2552
# Skip 2553
# Skip 2554
# Skip 2555
# Skip 2556
# Skip 2557
# Skip 2558
# Skip 2559
# Skip 2560
# Skip 2561
# Skip 2562
# Skip 2563
# Skip 2564
# Skip 2565
# Skip 2566
# Skip 2567
# Skip 2568
# Skip 2569
# Skip 2570
# Skip 2571
# Skip 2572
# Skip 2573
# Skip 2574
# Skip 2575
# Skip 2576
# Skip 2577
# Skip 2578
# Skip 2579
# Skip 2580
# Skip 2581
# Skip 2582
# Skip 2583
# Skip 2584
# Skip 2585
# Skip 2586
# Skip 2587
# Skip 2588
# Skip 2589
# Skip 2590
# Skip 2591
# Skip 2592
# Skip 2593
# Skip 2594
# Skip 2595
# Skip 2596
# Skip 2597
# Skip 2598
# Skip 2599
# Skip 2600
# Skip 2601
# Skip 2602
# Skip 2603
# Skip 2604
# Skip 2605
# Skip 2606
# Skip 2607
# Skip 2608
# Skip 2609
# Skip 2610
# Skip 2611
# Skip 2612
# Skip 2613
# Skip 2614
# Skip 2615
# Skip 2616
# Skip 2617
# Skip 2618
# Skip 2619
# Skip 2620
# Skip 2621
# Skip 2622
# Skip 2623
# Skip 2624
# Skip 2625
# Skip 2626
# Skip 2627
# Skip 2628
# Skip 2629
# Skip 2630
# Skip 2631
# Skip 2632
# Skip 2633
# Skip 2634
# Skip 2635
# Skip 2636
# Skip 2637
# Skip 2638
# Skip 2639
# Skip 2640
# Skip 2641
# Skip 2642
# Skip 2643
# Skip 2644
# Skip 2645
# Skip 2646
# Skip 2647
# Skip 2648
# Skip 2649
# Skip 2650
# Skip 2651
# Skip 2652
# Skip 2653
# Skip 2654
# Skip 2655
# Skip 2656
# Skip 2657
# Skip 2658
# Skip 2659
# Skip 2660
# Skip 2661
# Skip 2662
# Skip 2663
# Skip 2664
# Skip 2665
# Skip 2666
# Skip 2667
# Skip 2668
# Skip 2669
# Skip 2670
# Skip 2671
# Skip 2672
# Skip 2673
# Skip 2674
# Skip 2675
# Skip 2676
# Skip 2677
# Skip 2678
# Skip 2679
# Skip 2680
# Skip 2681
# Skip 2682
# Skip 2683
# Skip 2684
# Skip 2685
# Skip 2686
# Skip 2687
# Skip 2688
# Skip 2689
# Skip 2690
# Skip 2691
# Skip 2692
# Skip 2693
# Skip 2694
# Skip 2695
# Skip 2696
# Skip 2697
# Skip 2698
# Skip 2699
# Skip 2700
# Skip 2701
# Skip 2702
# Skip 2703
# Skip 2704
# Skip 2705
# Skip 2706
# Skip 2707
# Skip 2708
# Skip 2709
# Skip 2710
# Skip 2711
# Skip 2712
# Skip 2713
# Skip 2714
# Skip 2715
# Skip 2716
# Skip 2717
# Skip 2718
# Skip 2719
# Skip 2720
# Skip 2721
# Skip 2722
# Skip 2723
# Skip 2724
# Skip 2725
# Skip 2726
# Skip 2727
# Skip 2728
# Skip 2729
# Skip 2730
# Skip 2731
# Skip 2732
# Skip 2733
# Skip 2734
# Skip 2735
# Skip 2736
# Skip 2737
# Skip 2738
# Skip 2739
# Skip 2740
# Skip 2741
# Skip 2742
# Skip 2743
# Skip 2744
# Skip 2745
# Skip 2746
# Skip 2747
# Skip 2748
# Skip 2749
# Skip 2750
# Skip 2751
# Skip 2752
# Skip 2753
# Skip 2754
# Skip 2755
# Skip 2756
# Skip 2757
# Skip 2758
# Skip 2759
# Skip 2760
# Skip 2761
# Skip 2762
# Skip 2763
# Skip 2764
# Skip 2765
# Skip 2766
# Skip 2767
# Skip 2768
# Skip 2769
# Skip 2770
# Skip 2771
# Skip 2772
# Skip 2773
# Skip 2774
# Skip 2775
# Skip 2776
# Skip 2777
# Skip 2778
# Skip 2779
# Skip 2780
# Skip 2781
# Skip 2782
# Skip 2783
# Skip 2784
# Skip 2785
# Skip 2786
# Skip 2787
# Skip 2788
# Skip 2789
# Skip 2790
# Skip 2791
# Skip 2792
# Skip 2793
# Skip 2794
# Skip 2795
# Skip 2796
# Skip 2797
# Skip 2798
# Skip 2799
# Skip 2800
# Skip 2801
# Skip 2802
# Skip 2803
# Skip 2804
# Skip 2805
# Skip 2806
# Skip 2807
# Skip 2808
# Skip 2809
# Skip 2810
# Skip 2811
# Skip 2812
# Skip 2813
# Skip 2814
# Skip 2815
# Skip 2816
# Skip 2817
# Skip 2818
# Skip 2819
# Skip 2820
# Skip 2821
# Skip 2822
# Skip 2823
# Skip 2824
# Skip 2825
# Skip 2826
# Skip 2827
# Skip 2828
# Skip 2829
# Skip 2830
# Skip 2831
# Skip 2832
# Skip 2833
# Skip 2834
# Skip 2835
# Skip 2836
# Skip 2837
# Skip 2838
# Skip 2839
# Skip 2840
# Skip 2841
# Skip 2842
# Skip 2843
# Skip 2844
# Skip 2845
# Skip 2846
# Skip 2847
# Skip 2848
# Skip 2849
# Skip 2850
# Skip 2851
# Skip 2852
# Skip 2853
# Skip 2854
# Skip 2855
# Skip 2856
# Skip 2857
# Skip 2858
# Skip 2859
# Skip 2860
# Skip 2861
# Skip 2862
# Skip 2863
# Skip 2864
# Skip 2865
# Skip 2866
# Skip 2867
# Skip 2868
# Skip 2869
# Skip 2870
# Skip 2871
# Skip 2872
# Skip 2873
# Skip 2874
# Skip 2875
# Skip 2876
# Skip 2877
# Skip 2878
# Skip 2879
# Skip 2880
# Skip 2881
# Skip 2882
# Skip 2883
# Skip 2884
# Skip 2885
# Skip 2886
# Skip 2887
# Skip 2888
# Skip 2889
# Skip 2890
# Skip 2891
# Skip 2892
# Skip 2893
# Skip 2894
# Skip 2895
# Skip 2896
# Skip 2897
# Skip 2898
# Skip 2899
# Skip 2900
# Skip 2901
# Skip 2902
# Skip 2903
# Skip 2904
# Skip 2905
# Skip 2906
# Skip 2907
# Skip 2908
# Skip 2909
# Skip 2910
# Skip 2911
# Skip 2912
# Skip 2913
# Skip 2914
# Skip 2915
# Skip 2916
# Skip 2917
# Skip 2918
# Skip 2919
# Skip 2920
# Skip 2921
# Skip 2922
# Skip 2923
# Skip 2924
# Skip 2925
# Skip 2926
# Skip 2927
# Skip 2928
# Skip 2929
# Skip 2930
# Skip 2931
# Skip 2932
# Skip 2933
# Skip 2934
# Skip 2935
# Skip 2936
# Skip 2937
# Skip 2938
# Skip 2939
# Skip 2940
# Skip 2941
# Skip 2942
# Skip 2943
# Skip 2944
# Skip 2945
# Skip 2946
# Skip 2947
# Skip 2948
# Skip 2949
# Skip 2950
# Skip 2951
# Skip 2952
# Skip 2953
# Skip 2954
# Skip 2955
# Skip 2956
# Skip 2957
# Skip 2958
# Skip 2959
# Skip 2960
# Skip 2961
# Skip 2962
# Skip 2963
# Skip 2964
# Skip 2965
# Skip 2966
# Skip 2967
# Skip 2968
# Skip 2969
# Skip 2970
# Skip 2971
# Skip 2972
# Skip 2973
# Skip 2974
# Skip 2975
# Skip 2976
# Skip 2977
# Skip 2978
# Skip 2979
# Skip 2980
# Skip 2981
# Skip 2982
# Skip 2983
# Skip 2984
# Skip 2985
# Skip 2986
# Skip 2987
# Skip 2988
# Skip 2989
# Skip 2990
# Skip 2991
# Skip 2992
# Skip 2993
# Skip 2994
# Skip 2995
# Skip 2996
# Skip 2997
# Skip 2998
# Skip 2999
# Skip 3000
# Skip 3001
# Skip 3002
# Skip 3003
# Skip 3004
# Skip 3005
# Skip 3006
# Skip 3007
# Skip 3008
# Skip 3009
# Skip 3010
# Skip 3011
# Skip 3012
# Skip 3013
# Skip 3014
# Skip 3015
# Skip 3016
# Skip 3017
# Skip 3018
# Skip 3019
# Skip 3020
# Skip 3021
# Skip 3022
# Skip 3023
# Skip 3024
# Skip 3025
# Skip 3026
# Skip 3027
# Skip 3028
# Skip 3029
# Skip 3030
# Skip 3031
# Skip 3032
# Skip 3033
# Skip 3034
# Skip 3035
# Skip 3036
# Skip 3037
# Skip 3038
# Skip 3039
# Skip 3040
# Skip 3041
# Skip 3042
# Skip 3043
# Skip 3044
# Skip 3045
# Skip 3046
# Skip 3047
# Skip 3048
# Skip 3049
# Skip 3050
# Skip 3051
# Skip 3052
# Skip 3053
# Skip 3054
# Skip 3055
# Skip 3056
# Skip 3057
# Skip 3058
# Skip 3059
# Skip 3060
# Skip 3061
# Skip 3062
# Skip 3063
# Skip 3064
# Skip 3065
# Skip 3066
# Skip 3067
# Skip 3068
# Skip 3069
# Skip 3070
# Skip 3071
# Skip 3072
# Skip 3073
# Skip 3074
# Skip 3075
# Skip 3076
# Skip 3077
# Skip 3078
# Skip 3079
# Skip 3080
# Skip 3081
# Skip 3082
# Skip 3083
# Skip 3084
# Skip 3085
# Skip 3086
# Skip 3087
# Skip 3088
# Skip 3089
# Skip 3090
# Skip 3091
# Skip 3092
# Skip 3093
# Skip 3094
# Skip 3095
# Skip 3096
# Skip 3097
# Skip 3098
# Skip 3099
# Skip 3100
# Skip 3101
# Skip 3102
# Skip 3103
# Skip 3104
# Skip 3105
# Skip 3106
# Skip 3107
# Skip 3108
# Skip 3109
# Skip 3110
# Skip 3111
# Skip 3112
# Skip 3113
# Skip 3114
# Skip 3115
# Skip 3116
# Skip 3117
# Skip 3118
# Skip 3119
# Skip 3120
# Skip 3121
# Skip 3122
# Skip 3123
# Skip 3124
# Skip 3125
# Skip 3126
# Skip 3127
# Skip 3128
# Skip 3129
# Skip 3130
# Skip 3131
# Skip 3132
# Skip 3133
# Skip 3134
# Skip 3135
# Skip 3136
# Skip 3137
# Skip 3138
# Skip 3139
# Skip 3140
# Skip 3141
# Skip 3142
# Skip 3143
# Skip 3144
# Skip 3145
# Skip 3146
# Skip 3147
# Skip 3148
# Skip 3149
# Skip 3150
# Skip 3151
# Skip 3152
# Skip 3153
# Skip 3154
# Skip 3155
# Skip 3156
# Skip 3157
# Skip 3158
# Skip 3159
# Skip 3160
# Skip 3161
# Skip 3162
# Skip 3163
# Skip 3164
# Skip 3165
# Skip 3166
# Skip 3167
# Skip 3168
# Skip 3169
# Skip 3170
# Skip 3171
# Skip 3172
# Skip 3173
# Skip 3174
# Skip 3175
# Skip 3176
# Skip 3177
# Skip 3178
# Skip 3179
# Skip 3180
# Skip 3181
# Skip 3182
# Skip 3183
# Skip 3184
# Skip 3185
# Skip 3186
# Skip 3187
# Skip 3188
# Skip 3189
# Skip 3190
# Skip 3191
# Skip 3192
# Skip 3193
# Skip 3194
# Skip 3195
# Skip 3196
# Skip 3197
# Skip 3198
# Skip 3199
# Skip 3200
# Skip 3201
# Skip 3202
# Skip 3203
# Skip 3204
# Skip 3205
# Skip 3206
# Skip 3207
# Skip 3208
# Skip 3209
# Skip 3210
# Skip 3211
# Skip 3212
# Skip 3213
# Skip 3214
# Skip 3215
# Skip 3216
# Skip 3217
# Skip 3218
# Skip 3219
# Skip 3220
# Skip 3221
# Skip 3222
# Skip 3223
# Skip 3224
# Skip 3225
# Skip 3226
# Skip 3227
# Skip 3228
# Skip 3229
# Skip 3230
# Skip 3231
# Skip 3232
# Skip 3233
# Skip 3234
# Skip 3235
# Skip 3236
# Skip 3237
# Skip 3238
# Skip 3239
# Skip 3240
# Skip 3241
# Skip 3242
# Skip 3243
# Skip 3244
# Skip 3245
# Skip 3246
# Skip 3247
# Skip 3248
# Skip 3249
# Skip 3250
# Skip 3251
# Skip 3252
# Skip 3253
# Skip 3254
# Skip 3255
# Skip 3256
# Skip 3257
# Skip 3258
# Skip 3259
# Skip 3260
# Skip 3261
# Skip 3262
# Skip 3263
# Skip 3264
# Skip 3265
# Skip 3266
# Skip 3267
# Skip 3268
# Skip 3269
# Skip 3270
# Skip 3271
# Skip 3272
# Skip 3273
# Skip 3274
# Skip 3275
# Skip 3276
# Skip 3277
# Skip 3278
# Skip 3279
# Skip 3280
# Skip 3281
# Skip 3282
# Skip 3283
# Skip 3284
# Skip 3285
# Skip 3286
# Skip 3287
# Skip 3288
# Skip 3289
# Skip 3290
# Skip 3291
# Skip 3292
# Skip 3293
# Skip 3294
# Skip 3295
# Skip 3296
# Skip 3297
# Skip 3298
# Skip 3299
# Skip 3300
# Skip 3301
# Skip 3302
# Skip 3303
# Skip 3304
# Skip 3305
# Skip 3306
# Skip 3307
# Skip 3308
# Skip 3309
# Skip 3310
# Skip 3311
# Skip 3312
# Skip 3313
# Skip 3314
# Skip 3315
# Skip 3316
# Skip 3317
# Skip 3318
# Skip 3319
# Skip 3320
# Skip 3321
# Skip 3322
# Skip 3323
# Skip 3324
# Skip 3325
# Skip 3326
# Skip 3327
# Skip 3328
# Skip 3329
# Skip 3330
# Skip 3331
# Skip 3332
# Skip 3333
# Skip 3334
# Skip 3335
# Skip 3336
# Skip 3337
# Skip 3338
# Skip 3339
# Skip 3340
# Skip 3341
# Skip 3342
# Skip 3343
# Skip 3344
# Skip 3345
# Skip 3346
# Skip 3347
# Skip 3348
# Skip 3349
# Skip 3350
# Skip 3351
# Skip 3352
# Skip 3353
# Skip 3354
# Skip 3355
# Skip 3356
# Skip 3357
# Skip 3358
# Skip 3359
# Skip 3360
# Skip 3361
# Skip 3362
# Skip 3363
# Skip 3364
# Skip 3365
# Skip 3366
# Skip 3367
# Skip 3368
# Skip 3369
# Skip 3370
# Skip 3371
# Skip 3372
# Skip 3373
# Skip 3374
# Skip 3375
# Skip 3376
# Skip 3377
# Skip 3378
# Skip 3379
# Skip 3380
# Skip 3381
# Skip 3382
# Skip 3383
# Skip 3384
# Skip 3385
# Skip 3386
# Skip 3387
# Skip 3388
# Skip 3389
# Skip 3390
# Skip 3391
# Skip 3392
# Skip 3393
# Skip 3394
# Skip 3395
# Skip 3396
# Skip 3397
# Skip 3398
# Skip 3399
# Skip 3400
# Skip 3401
# Skip 3402
# Skip 3403
# Skip 3404
# Skip 3405
# Skip 3406
# Skip 3407
# Skip 3408
# Skip 3409
# Skip 3410
# Skip 3411
# Skip 3412
# Skip 3413
# Skip 3414
# Skip 3415
# Skip 3416
# Skip 3417
# Skip 3418
# Skip 3419
# Skip 3420
# Skip 3421
# Skip 3422
# Skip 3423
# Skip 3424
# Skip 3425
# Skip 3426
# Skip 3427
# Skip 3428
# Skip 3429
# Skip 3430
# Skip 3431
# Skip 3432
# Skip 3433
# Skip 3434
# Skip 3435
# Skip 3436
# Skip 3437
# Skip 3438
# Skip 3439
# Skip 3440
# Skip 3441
# Skip 3442
# Skip 3443
# Skip 3444
# Skip 3445
# Skip 3446
# Skip 3447
# Skip 3448
# Skip 3449
# Skip 3450
# Skip 3451
# Skip 3452
# Skip 3453
# Skip 3454
# Skip 3455
# Skip 3456
# Skip 3457
# Skip 3458
# Skip 3459
# Skip 3460
# Skip 3461
# Skip 3462
# Skip 3463
# Skip 3464
# Skip 3465
# Skip 3466
# Skip 3467
# Skip 3468
# Skip 3469
# Skip 3470
# Skip 3471
# Skip 3472
# Skip 3473
# Skip 3474
# Skip 3475
# Skip 3476
# Skip 3477
# Skip 3478
# Skip 3479
# Skip 3480
# Skip 3481
# Skip 3482
# Skip 3483
# Skip 3484
# Skip 3485
# Skip 3486
# Skip 3487
# Skip 3488
# Skip 3489
# Skip 3490
# Skip 3491
# Skip 3492
# Skip 3493
# Skip 3494
# Skip 3495
# Skip 3496
# Skip 3497
# Skip 3498
# Skip 3499
# Skip 3500
# Skip 3501
# Skip 3502
# Skip 3503
# Skip 3504
# Skip 3505
# Skip 3506
# Skip 3507
# Skip 3508
# Skip 3509
# Skip 3510
# Skip 3511
# Skip 3512
# Skip 3513
# Skip 3514
# Skip 3515
# Skip 3516
# Skip 3517
# Skip 3518
# Skip 3519
# Skip 3520
# Skip 3521
# Skip 3522
# Skip 3523
# Skip 3524
# Skip 3525
# Skip 3526
# Skip 3527
# Skip 3528
# Skip 3529
# Skip 3530
# Skip 3531
# Skip 3532
# Skip 3533
# Skip 3534
# Skip 3535
# Skip 3536
# Skip 3537
# Skip 3538
# Skip 3539
# Skip 3540
# Skip 3541
# Skip 3542
# Skip 3543
# Skip 3544
# Skip 3545
# Skip 3546
# Skip 3547
# Skip 3548
# Skip 3549
# Skip 3550
# Skip 3551
# Skip 3552
# Skip 3553
# Skip 3554
# Skip 3555
# Skip 3556
# Skip 3557
# Skip 3558
# Skip 3559
# Skip 3560
# Skip 3561
# Skip 3562
# Skip 3563
# Skip 3564
# Skip 3565
# Skip 3566
# Skip 3567
# Skip 3568
# Skip 3569
# Skip 3570
# Skip 3571
# Skip 3572
# Skip 3573
# Skip 3574
# Skip 3575
# Skip 3576
# Skip 3577
# Skip 3578
# Skip 3579
# Skip 3580
# Skip 3581
# Skip 3582
# Skip 3583
# Skip 3584
# Skip 3585
# Skip 3586
# Skip 3587
# Skip 3588
# Skip 3589
# Skip 3590
# Skip 3591
# Skip 3592
# Skip 3593
# Skip 3594
# Skip 3595
# Skip 3596
# Skip 3597
# Skip 3598
# Skip 3599
# Skip 3600
# Skip 3601
# Skip 3602
# Skip 3603
# Skip 3604
# Skip 3605
# Skip 3606
# Skip 3607
# Skip 3608
# Skip 3609
# Skip 3610
# Skip 3611
# Skip 3612
# Skip 3613
# Skip 3614
# Skip 3615
# Skip 3616
# Skip 3617
# Skip 3618
# Skip 3619
# Skip 3620
# Skip 3621
# Skip 3622
# Skip 3623
# Skip 3624
# Skip 3625
# Skip 3626
# Skip 3627
# Skip 3628
# Skip 3629
# Skip 3630
# Skip 3631
# Skip 3632
# Skip 3633
# Skip 3634
# Skip 3635
# Skip 3636
# Skip 3637
# Skip 3638
# Skip 3639
# Skip 3640
# Skip 3641
# Skip 3642
# Skip 3643
# Skip 3644
# Skip 3645
# Skip 3646
# Skip 3647
# Skip 3648
# Skip 3649
# Skip 3650
# Skip 3651
# Skip 3652
# Skip 3653
# Skip 3654
# Skip 3655
# Skip 3656
# Skip 3657
# Skip 3658
# Skip 3659
# Skip 3660
# Skip 3661
# Skip 3662
# Skip 3663
# Skip 3664
# Skip 3665
# Skip 3666
# Skip 3667
# Skip 3668
# Skip 3669
# Skip 3670
# Skip 3671
# Skip 3672
# Skip 3673
# Skip 3674
# Skip 3675
# Skip 3676
# Skip 3677
# Skip 3678
# Skip 3679
# Skip 3680
# Skip 3681
# Skip 3682
# Skip 3683
# Skip 3684
# Skip 3685
# Skip 3686
# Skip 3687
# Skip 3688
# Skip 3689
# Skip 3690
# Skip 3691
# Skip 3692
# Skip 3693
# Skip 3694
# Skip 3695
# Skip 3696
# Skip 3697
# Skip 3698
# Skip 3699
# Skip 3700
# Skip 3701
# Skip 3702
# Skip 3703
# Skip 3704
# Skip 3705
# Skip 3706
# Skip 3707
# Skip 3708
# Skip 3709
# Skip 3710
# Skip 3711
# Skip 3712
# Skip 3713
# Skip 3714
# Skip 3715
# Skip 3716
# Skip 3717
# Skip 3718
# Skip 3719
# Skip 3720
# Skip 3721
# Skip 3722
# Skip 3723
# Skip 3724
# Skip 3725
# Skip 3726
# Skip 3727
# Skip 3728
# Skip 3729
# Skip 3730
# Skip 3731
# Skip 3732
# Skip 3733
# Skip 3734
# Skip 3735
# Skip 3736
# Skip 3737
# Skip 3738
# Skip 3739
# Skip 3740
# Skip 3741
# Skip 3742
# Skip 3743
# Skip 3744
# Skip 3745
# Skip 3746
# Skip 3747
# Skip 3748
# Skip 3749
# Skip 3750
# Skip 3751
# Skip 3752
# Skip 3753
# Skip 3754
# Skip 3755
# Skip 3756
# Skip 3757
# Skip 3758
# Skip 3759
# Skip 3760
# Skip 3761
# Skip 3762
# Skip 3763
# Skip 3764
# Skip 3765
# Skip 3766
# Skip 3767
# Skip 3768
# Skip 3769
# Skip 3770
# Skip 3771
# Skip 3772
# Skip 3773
# Skip 3774
# Skip 3775
# Skip 3776
# Skip 3777
# Skip 3778
# Skip 3779
# Skip 3780
# Skip 3781
# Skip 3782
# Skip 3783
# Skip 3784
# Skip 3785
# Skip 3786
# Skip 3787
# Skip 3788
# Skip 3789
# Skip 3790
# Skip 3791
# Skip 3792
# Skip 3793
# Skip 3794
# Skip 3795
# Skip 3796
# Skip 3797
# Skip 3798
# Skip 3799
# Skip 3800

# %%
company_name = "UDR INC"
ticker = "UG"
sector = 4

base_directory = f'./sec-edgar-filings/{ticker}/10-K'
output_directory = f'./Health and Medical/{ticker}.csv'

check = download_10k_filings(ticker)

output_df = process_10k_filings(ticker, company_name, base_directory)
output_df = output_df.sort_values(by="Fill Date", ascending=False)
output_df.to_csv(output_directory)
display(output_df)
# Out:
# Failed to restart the Kernel.
#
# Unable to start Kernel 'ML (Python 3.9.18)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
